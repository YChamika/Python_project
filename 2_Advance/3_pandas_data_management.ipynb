# %%
#Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
#Data Cleanup
df ['job_posted_date'] = pd.to_datetime(df ['job_posted_date'])
# Out:
# '[WinError 10054] An existing connection was forcibly closed by the remote host' thrown while requesting HEAD https://huggingface.co/datasets/lukebarousse/data_jobs/resolve/ed776e5a0a8c40ea9d5efbd800772ae52e140f3e/data_jobs.py
# Retrying in 1s [Retry 1/5].
# Using the latest cached version of the dataset since lukebarousse/data_jobs couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\CHAMIKA\.cache\huggingface\datasets\lukebarousse___data_jobs\default\0.0.0\ed776e5a0a8c40ea9d5efbd800772ae52e140f3e (last modified on Sat Feb  7 04:56:30 2026).

# %%
df.sample(10, random_state=40)
# Out:
#               job_title_short                                 job_title  \
# 650315   Senior Data Engineer                     Sr. Big Data Engineer
# 28072          Data Scientist                            Data Scientist
# 86657          Data Scientist                Consultant(e) Data Science
# 678850           Data Analyst        Enterprise Data Operations Analyst
# 154301           Data Analyst  Produktionsplaner / Data Analyst (m|w|d)
# 275846           Data Analyst                           HR Data Analyst
# 684564           Data Analyst                              Data Analyst
# 263956      Software Engineer                    Senior DevOps Engineer
# 442931  Senior Data Scientist   Executive (Data Strategy & Performance)
# 359179           Data Analyst                       Medior Data Analist
#
#                                              job_location  \
# 650315                                        Atlanta, GA
# 28072                                           Argentina
# 86657                                       Paris, France
# 678850                      Peeramcheru, Telangana, India
# 154301                                 Bopfingen, Germany
# 275846                                      Madrid, Spain
# 684564                                          Hong Kong
# 263956                                         Lima, Peru
# 442931  Kuala Lumpur, Federal Territory of Kuala Lumpu...
# 359179                             Eindhoven, Netherlands
#
#                                               job_via job_schedule_type  \
# 650315                                   via LinkedIn         Full-time
# 28072                                    via LinkedIn         Full-time
# 86657                                 via Recruit.net         Full-time
# 678850                                   via LinkedIn         Full-time
# 154301                                      via BeBee         Full-time
# 275846                                      via BeBee         Full-time
# 684564                                via Trabajo.org         Full-time
# 263956  via Trabajo.org - Vacantes De Empleo, Trabajo         Full-time
# 442931                             via BeBee Malaysia         Full-time
# 359179                     via Nationale Vacaturebank         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 650315               False         Georgia 2023-02-03 11:05:29
# 28072                False       Argentina 2023-09-25 13:48:48
# 86657                False          France 2023-03-19 00:25:53
# 678850               False           India 2023-11-02 10:13:44
# 154301               False         Germany 2023-11-11 08:15:32
# 275846               False           Spain 2023-06-15 07:30:03
# 684564               False       Hong Kong 2023-07-29 10:20:00
# 263956               False            Peru 2023-08-30 07:24:48
# 442931               False        Malaysia 2023-01-14 16:18:32
# 359179               False     Netherlands 2023-01-07 23:11:53
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 650315                  False                 False  United States
# 28072                   False                 False      Argentina
# 86657                   False                 False         France
# 678850                  False                 False          India
# 154301                   True                 False        Germany
# 275846                   True                 False          Spain
# 684564                   True                 False      Hong Kong
# 263956                   True                 False           Peru
# 442931                  False                 False       Malaysia
# 359179                  False                 False    Netherlands
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 650315        None              NaN              NaN
# 28072         None              NaN              NaN
# 86657         None              NaN              NaN
# 678850        None              NaN              NaN
# 154301        None              NaN              NaN
# 275846        None              NaN              NaN
# 684564        None              NaN              NaN
# 263956        None              NaN              NaN
# 442931        None              NaN              NaN
# 359179        None              NaN              NaN
#
#                                 company_name  \
# 650315          Norfolk Southern Corporation
# 28072                          Banco Galicia
# 86657                           Sia Partners
# 678850                               PepsiCo
# 154301                     Voith SE & Co. KG
# 275846         Securitas Direct España S.A.U
# 684564                 Swing Consulting Ltd.
# 263956                               Emprego
# 442931  Petroliam Nasional Berhad (PETRONAS)
# 359179                                   TMC
#
#                                                job_skills  \
# 650315  ['sql', 'scala', 'python', 'nosql', 'shell', '...
# 28072                              ['sql', 'r', 'python']
# 86657   ['r', 'sas', 'sas', 'python', 'perl', 'bash', ...
# 678850  ['c#', 'sql', 'sql server', 'azure', 'react', ...
# 154301  ['sql', 'vba', 'python', 'javascript', 'sap', ...
# 275846         ['r', 'excel', 'spss', 'qlik', 'power bi']
# 684564                              ['python', 'tableau']
# 263956  ['java', 'python', 'go', 'kotlin', 'azure', 'a...
# 442931                                               None
# 359179                    ['python', 'sql', 'databricks']
#
#                                           job_type_skills
# 650315  {'cloud': ['aws', 'gcp'], 'databases': ['cassa...
# 28072             {'programming': ['sql', 'r', 'python']}
# 86657   {'analyst_tools': ['sas'], 'programming': ['r'...
# 678850  {'cloud': ['azure'], 'databases': ['sql server...
# 154301  {'analyst_tools': ['sap', 'ms access'], 'progr...
# 275846  {'analyst_tools': ['excel', 'spss', 'qlik', 'p...
# 684564  {'analyst_tools': ['tableau'], 'programming': ...
# 263956  {'cloud': ['azure', 'aws', 'gcp'], 'libraries'...
# 442931                                               None
# 359179  {'cloud': ['databricks'], 'programming': ['pyt...

# %%
df_altered = df.copy()

# %%
median_salary_year = df['salary_year_avg'].median()
median_salary_hour = df['salary_hour_avg'].median()

df_altered['salary_year_avg'] = df['salary_year_avg'].fillna(median_salary_year)
df_altered['salary_hour_avg'] = df['salary_hour_avg'].fillna(median_salary_hour)

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
